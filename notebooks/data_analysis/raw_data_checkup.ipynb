# %%
import polars as pl
from pathlib import Path

# %%
resampled_data_path = Path(
    "/home/bobby/repos/latent-neural-dynamics-modeling/resampled_recordings"
)
participants = "participants_2"

# %%
participant = "PDI1"
session = 4
block = 2

# %%
participants_df = pl.read_parquet(
    resampled_data_path
    / participants
    / f"participant_id={participant}"
    / f"session={session}"
    / f"block={block}"
    / "*"
)

# %%
participants_df
# Out:
# shape: (12, 98)
# ┌─────────────┬─────────┬───────┬───────┬───┬─────────────┬─────────────┬─────────────┬────────────┐
# │ participant ┆ session ┆ block ┆ trial ┆ … ┆ ECOG_4_psd_ ┆ x           ┆ y           ┆ tracing_sp │
# │ _id         ┆ ---     ┆ ---   ┆ ---   ┆   ┆ values      ┆ ---         ┆ ---         ┆ eed        │
# │ ---         ┆ u32     ┆ u64   ┆ u64   ┆   ┆ ---         ┆ list[i64]   ┆ list[i64]   ┆ ---        │
# │ str         ┆         ┆       ┆       ┆   ┆ list[list[f ┆             ┆             ┆ list[f64]  │
# │             ┆         ┆       ┆       ┆   ┆ 64]]        ┆             ┆             ┆            │
# ╞═════════════╪═════════╪═══════╪═══════╪═══╪═════════════╪═════════════╪═════════════╪════════════╡
# │ PDI1        ┆ 4       ┆ 2     ┆ 1     ┆ … ┆ [[4.7324e-1 ┆ [-377,      ┆ [37, 46, …  ┆ [154.50478 │
# │             ┆         ┆       ┆       ┆   ┆ 2,          ┆ -387, …     ┆ -58]        ┆ 8, 154.504 │
# ...
